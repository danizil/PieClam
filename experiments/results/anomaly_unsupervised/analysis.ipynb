# %%
import os
import pandas as pd
import sys
if '..' not in sys.path:
    sys.path.insert(0, '..')

if '../..' not in sys.path:
    sys.path.insert(0, '../..')


import optimization_utils as ou


#todo: remake this and the distance files to be able to print the results LOOK AT HOW ITS SUPPOSED TO BE BEFORE RUNNING!!!!!
#todo: maybe i dont need to print those results maybe it's ok with the jupyter
#TODO; DISTANCE

#TODO: TEST ALL LINK PREDICTIONS



# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
#todo: print with the correct accuracy names.
#THE ONE I'M WORKING ON
#todo: the acc configs should contain the results of the 3 datasets for each config
print('ieclam reddit:')

ou.print_folder(model_name='ieclam',
                ds_name='photo', 
                task='anomaly_unsupervised',
                sort_by='prior')
# Out:
# ieclam reddit:
#
#
# /Users/danielzilberg/Documents/Learned_Graphon/ICML_PieClam_020425/experiments/results/anomaly_unsupervised/../../optimization_utils.py:451:::  no test or val accuracy scores in the file
#     acc_configs_0.json
#     ==================
# The file in /Users/danielzilberg/Documents/Learned_Graphon/ICML_PieClam_020425/experiments/results/anomaly_unsupervised/ieclam/photo/acc_configs_0.json has no results, consider deleting.
#
#
#
# /Users/danielzilberg/Documents/Learned_Graphon/ICML_PieClam_020425/experiments/results/anomaly_unsupervised/../../optimization_utils.py:451:::  no test or val accuracy scores in the file
#     acc_configs_1.json
#     ==================
# The file in /Users/danielzilberg/Documents/Learned_Graphon/ICML_PieClam_020425/experiments/results/anomaly_unsupervised/ieclam/photo/acc_configs_1.json has no results, consider deleting.
#
#
#
# /Users/danielzilberg/Documents/Learned_Graphon/ICML_PieClam_020425/experiments/results/anomaly_unsupervised/../../optimization_utils.py:451:::  no test or val accuracy scores in the file
#     acc_configs_6.json
#     ==================
# The file in /Users/danielzilberg/Documents/Learned_Graphon/ICML_PieClam_020425/experiments/results/anomaly_unsupervised/ieclam/photo/acc_configs_6.json has no results, consider deleting.
#
#     acc_configs_4.json
#     ==================
#     Base config:
# {
#     "clamiter_init": {
#         "dim_feat": 56,
#         "s_reg": 0.0,
#         "l1_reg": 1,
#         "T": 1,
#         "hidden_dim": 64,
#         "num_coupling_blocks": 32,
#         "num_layers_mlp": 2
#     },
#     "feat_opt": {
#         "lr": 1e-06,
#         "n_iter": 7000,
#         "early_stop": 0
#     }
# }
#     ==================
#    avg_vanilla_star  std_vanilla_star  avg_prior  std_prior  avg_prior_star  \
# 0          0.538047          0.008528        NaN        NaN             NaN
# 1          0.568480          0.007550        NaN        NaN             NaN
#
#    std_prior_star  count  clamiter_init_s_reg  clamiter_init_l1_reg  \
# 0             NaN      3                  0.0                   1.0
# 1             NaN      2                  0.0                   1.0
#
#    clamiter_init_dim_feat  feat_opt_n_iter  feat_opt_lr
# 0                      22              200     0.000004
# 1                      24              200     0.000004
#
#
#
#
# /Users/danielzilberg/Documents/Learned_Graphon/ICML_PieClam_020425/experiments/results/anomaly_unsupervised/../../optimization_utils.py:451:::  no test or val accuracy scores in the file
#     acc_configs_5.json
#     ==================
# The file in /Users/danielzilberg/Documents/Learned_Graphon/ICML_PieClam_020425/experiments/results/anomaly_unsupervised/ieclam/photo/acc_configs_5.json has no results, consider deleting.
#
#
#
# /Users/danielzilberg/Documents/Learned_Graphon/ICML_PieClam_020425/experiments/results/anomaly_unsupervised/../../optimization_utils.py:451:::  no test or val accuracy scores in the file
#     acc_configs_2.json
#     ==================
# The file in /Users/danielzilberg/Documents/Learned_Graphon/ICML_PieClam_020425/experiments/results/anomaly_unsupervised/ieclam/photo/acc_configs_2.json has no results, consider deleting.
#
#
#
# /Users/danielzilberg/Documents/Learned_Graphon/ICML_PieClam_020425/experiments/results/anomaly_unsupervised/../../optimization_utils.py:451:::  no test or val accuracy scores in the file
#     acc_configs.json
#     ==================
# The file in /Users/danielzilberg/Documents/Learned_Graphon/ICML_PieClam_020425/experiments/results/anomaly_unsupervised/ieclam/photo/acc_configs.json has no results, consider deleting.
#
#
#
# /Users/danielzilberg/Documents/Learned_Graphon/ICML_PieClam_020425/experiments/results/anomaly_unsupervised/../../optimization_utils.py:451:::  no test or val accuracy scores in the file
#     acc_configs_3.json
#     ==================
# The file in /Users/danielzilberg/Documents/Learned_Graphon/ICML_PieClam_020425/experiments/results/anomaly_unsupervised/ieclam/photo/acc_configs_3.json has no results, consider deleting.

# %%
#todo: print with the correct accuracy names.

print('pieclam elliptic:')

ou.print_folder(model_name='pieclam',
                ds_name='elliptic', 
                sort_by='prior')
# Out:
# pieclam elliptic:
# acc_configs_0.json
# ==================
#
#    avg_vanilla_star  std_vanilla_star  avg_prior  std_prior  avg_prior_star  \
# 0          0.403692               NaN   0.529573        NaN        0.403746
# 1          0.402306               NaN   0.527900        NaN        0.402598
# 2          0.400159               NaN   0.525303        NaN        0.400556
# 3          0.401440               NaN   0.522330        NaN        0.401955
# 4          0.402658               NaN   0.521626        NaN        0.402642
# 5          0.400665               NaN   0.520162        NaN        0.400886
# 6          0.401308               NaN   0.520048        NaN        0.401131
# 7          0.395576               NaN   0.518690        NaN        0.395729
# 8          0.402683               NaN   0.516992        NaN        0.402866
# 9          0.401570               NaN   0.514308        NaN        0.401857
#
#    std_prior_star  count  clamiter_init_s_reg  clamiter_init_l1_reg  \
# 0             NaN      1                    0                 0.999
# 1             NaN      1                    0                 0.999
# 2             NaN      1                    0                 0.999
# 3             NaN      1                    0                 0.999
# 4             NaN      1                    0                 0.999
# 5             NaN      1                    0                 0.999
# 6             NaN      1                    0                 0.999
# 7             NaN      1                    0                 0.999
# 8             NaN      1                    0                 0.999
# 9             NaN      1                    0                 0.999
#
#    clamiter_init_dim_feat  feat_opt_n_iter  feat_opt_lr  prior_opt_n_iter  \
# 0                      28              550     0.000003              1250
# 1                      28              450     0.000003              1350
# 2                      28              450     0.000003              1350
# 3                      28              550     0.000003              1250
# 4                      28              450     0.000003              1250
# 5                      28              450     0.000003              1250
# 6                      28              550     0.000003              1250
# 7                      28              550     0.000003              1350
# 8                      28              450     0.000003              1350
# 9                      28              450     0.000003              1250
#
#    prior_opt_lr  prior_opt_noise_amp  back_forth_scheduler_gamma
# 0      0.000002                0.055                         0.4
# 1      0.000002                0.045                         0.4
# 2      0.000002                0.045                         0.6
# 3      0.000002                0.055                         0.6
# 4      0.000002                0.045                         0.4
# 5      0.000002                0.055                         0.6
# 6      0.000002                0.055                         0.4
# 7      0.000002                0.055                         0.4
# 8      0.000002                0.045                         0.6
# 9      0.000002                0.055                         0.6
# acc_configs.json
# ==================
#
#    avg_vanilla_star  std_vanilla_star  avg_prior  std_prior  avg_prior_star  \
# 0          0.404470               NaN   0.528260        NaN        0.404702
# 1          0.399907               NaN   0.525388        NaN        0.400427
# 2          0.398580               NaN   0.524027        NaN        0.398784
# 3          0.400093               NaN   0.522917        NaN        0.400423
# 4          0.398187               NaN   0.520658        NaN        0.399062
# 5          0.400840               NaN   0.519668        NaN        0.400896
# 6          0.401555               NaN   0.517686        NaN        0.401633
# 7          0.402155               NaN   0.516719        NaN        0.402480
# 8          0.402175               NaN   0.516677        NaN        0.402369
# 9          0.399092               NaN   0.516519        NaN        0.399133
#
#    std_prior_star  count  clamiter_init_s_reg  clamiter_init_l1_reg  \
# 0             NaN      1                  0.0                 1.001
# 1             NaN      1                  0.0                 1.001
# 2             NaN      1                  0.0                 0.999
# 3             NaN      1                  0.0                 0.999
# 4             NaN      1                  0.0                 1.001
# 5             NaN      1                  0.0                 1.001
# 6             NaN      1                  0.0                 1.001
# 7             NaN      1                  0.0                 1.001
# 8             NaN      1                  0.0                 0.999
# 9             NaN      1                  0.0                 1.001
#
#    clamiter_init_dim_feat  feat_opt_n_iter  feat_opt_lr  prior_opt_n_iter  \
# 0                      32              700     0.000003              1500
# 1                      32              700     0.000003              1100
# 2                      28              300     0.000003              1100
# 3                      28              300     0.000003              1500
# 4                      32              700     0.000003              1500
# 5                      32              300     0.000003              1500
# 6                      32              700     0.000003              1100
# 7                      28              700     0.000003              1500
# 8                      28              300     0.000003              1500
# 9                      28              700     0.000003              1100
#
#    prior_opt_lr  prior_opt_noise_amp  back_forth_scheduler_gamma
# 0      0.000002                 0.04                         0.4
# 1      0.000002                 0.06                         0.4
# 2      0.000002                 0.04                         0.4
# 3      0.000002                 0.04                         0.4
# 4      0.000002                 0.04                         0.6
# 5      0.000002                 0.06                         0.6
# 6      0.000002                 0.04                         0.6
# 7      0.000002                 0.06                         0.6
# 8      0.000002                 0.06                         0.4
# 9      0.000002                 0.04                         0.4
