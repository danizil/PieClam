# %%
import torch
import matplotlib.pyplot as plt
# local
import sys
if '..' not in sys.path:
    sys.path.insert(0, '..')

from datasets.import_dataset import import_dataset
from trainer import Trainer
import clamiter as ci
from utils.plotting import *

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f'device = {device}')


# %load_ext autoreload
# %autoreload 2
# Out:
# device = cuda

# %% [markdown]
# # SBM

# %%
# import sbm and bipartite
ds_sbm_halfdiag = import_dataset('sbm3x3HalfDiag')
ds_sbm_halfcenter = import_dataset('sbm3x3HalfCenter')
plot_adj(ds_sbm_halfcenter.edge_index)

# %% [markdown]
# ### Lorenz Inner

# %% [markdown]
# #### IEClam

# %%
config_triplets = [
                    # ['feat_opt', 'n_iter', 2000],
                    # ['feat_opt', 'lr', 0.00003],
                    # ['prior_opt', 'n_iter', 1500],
                    # ['prior_opt', 'lr', 0.0000005],
                    # ['back_forth','n_back_forth', 50],
                    # ['back_forth', 'first_func_in_fit', 'feat_opt']
                ]


trainer_halfdiag_iegam = Trainer(
                model_name='iegam',
                task='distance',
                device=device,
                config_triplets_to_change=config_triplets,
                dataset=ds_sbm_halfdiag.clone()
)

losses_halfdiag_iegam, logcut_halfdiag_iegam, l2_halfdiag_iegam = trainer_halfdiag_iegam.train(
    d = 0.2,
    plot_every=-1,
    init_feats=True,
    init_type='small_gaus',
    verbose=False,
    verbose_in_funcs=False
)
trainer_halfdiag_iegam.plot_state(node_size_factor=5)

del trainer_halfdiag_iegam.data
# Out:
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:301:::
#  starting optimization of iegam on sbm3x3HalfDiag on device cuda
#
#  configs_dict:
# {
#     "clamiter_init": {
#         "dim_feat": 4,
#         "dim_attr": 64,
#         "s_reg": 0.0,
#         "l1_reg": 0.05,
#         "T": 1,
#         "hidden_dim": 64,
#         "num_coupling_blocks": 32,
#         "num_layers_mlp": 2
#     },
#     "feat_opt": {
#         "lr": 1e-05,
#         "n_iter": 10000,
#         "early_stop": 0
#     }
# }
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:368:::
# fit wrapper fit_feats, plotting state at iter 9999
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:409:::
#
#
# FINISHED train model on params
#  last accuracies:
# log_cut: 0.23335474167636866
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:415:::

# %% [markdown]
# #### PieClam

# %%
config_triplets = [
                    # ['feat_opt', 'n_iter', 2000],
                    # ['feat_opt', 'lr', 0.00003],
                    # ['prior_opt', 'n_iter', 1500],
                    # ['prior_opt', 'lr', 0.0000005],
                    # ['back_forth','n_back_forth', 50],
                    # ['back_forth', 'first_func_in_fit', 'feat_opt']
                ]


trainer_halfdiag_piegam = Trainer(
                model_name='piegam',
                task='distance',
                device=device,
                config_triplets_to_change=config_triplets,
                dataset=ds_sbm_halfdiag.clone()
)

losses_halfdiag_piegam, logcut_halfdiag_piegam, l2_halfdiag_piegam = trainer_halfdiag_piegam.train(
    d = 0.2,
    plot_every=-1,
    init_feats=True,
    init_type='small_gaus',
    verbose=False,
    verbose_in_funcs=False
)
del trainer_halfdiag_piegam.data   
del trainer_halfdiag_piegam.clamiter.prior.model
# Out:
# /home/user/Documents/danny/AAAI_pieclam/tests/../trainer.py:311:::
#  starting optimization of piegam on sbm3x3HalfDiag on device cuda
#
#  configs_dict:
# {
#     "clamiter_init": {
#         "dim_feat": 4,
#         "dim_attr": 100,
#         "s_reg": 0.0,
#         "l1_reg": 0.0,
#         "T": 1,
#         "hidden_dim": 64,
#         "num_coupling_blocks": 32,
#         "num_layers_mlp": 2
#     },
#     "feat_opt": {
#         "lr": 1e-05,
#         "n_iter": 2000,
#         "early_stop": 0
#     },
#     "prior_opt": {
#         "n_iter": 2000,
#         "lr": 5e-06,
#         "noise_amp": 0.1,
#         "weight_decay": 0.01,
#         "early_stop": 0
#     },
#     "back_forth": {
#         "n_back_forth": 20,
#         "scheduler_step_size": 100,
#         "scheduler_gamma": 0.5,
#         "early_stop_fit": 0,
#         "first_func_in_fit": "fit_prior"
#     }
# }
#
#
# /home/user/Documents/danny/AAAI_pieclam/tests/../clamiter.py:546:::
# in fit,
# first_func_in_fit='fit_prior'
# second_function_name='fit_feats'
#
#
# /home/user/Documents/danny/AAAI_pieclam/tests/../clamiter.py:604:::
# back and forth 1/20
#
#
# /home/user/Documents/danny/AAAI_pieclam/tests/../clamiter.py:604:::
# back and forth 2/20
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[15], line 19
#       1 config_triplets = [
#       2                     # ['feat_opt', 'n_iter', 2000],
#       3                     # ['feat_opt', 'lr', 0.00003],
#    (...)
#       7                     # ['back_forth', 'first_func_in_fit', 'feat_opt']
#       8                 ]
#      11 trainer_halfdiag_piegam = Trainer(
#      12                 model_name='piegam',
#      13                 task=None,
#    (...)
#      16                 dataset=ds_sbm_halfdiag.clone()
#      17 )
# ---> 19 losses_halfdiag_piegam, logcut_halfdiag_piegam, l2_halfdiag_piegam = trainer_halfdiag_piegam.train(
#      20     d = 0.2,
#      21     plot_every=-1,
#      22     init_feats=True,
#      23     init_type='small_gaus',
#      24     verbose=False,
#      25     verbose_in_funcs=False
#      26 )
#      27 del trainer_halfdiag_piegam.data
#      28 del trainer_halfdiag_piegam.clamiter.prior.model
#
# File ~/Documents/danny/AAAI_pieclam/tests/../trainer.py:380, in Trainer.train(self, init_type, dyads_to_omit, task_params, init_feats, acc_every, performance_metric, prior_fit_mask, plot_every, verbose, verbose_in_funcs, node_feats_for_init, **kwargs)
#     366     self.scheduler = torch.optim.lr_scheduler.StepLR(
#     367             self.optimizer,
#     368             step_size=self.configs_dict['back_forth']['scheduler_step_size'],
#     369             gamma=self.configs_dict['back_forth']['scheduler_gamma'])
#     371 fit_opt_params = {
#     372         'feat_params': self.configs_dict['feat_opt'],
#     373         'prior_params': self.configs_dict['prior_opt'],
#    (...)
#     377         'early_stop_fit': self.configs_dict['back_forth']['early_stop_fit']
#     378         }
# --> 380 losses, accuracies_test, accuracies_val = self.clamiter.fit(
#     381                         self.data,
#     382                         optimizer=self.optimizer, scheduler=self.scheduler,
#     383                         dyads_to_omit=dyads_to_omit,
#     384                         prior_fit_mask=prior_fit_mask,
#     385
#     386                         task=self.task,
#     387                         acc_every=acc_every,
#     388                         performance_metric=performance_metric,
#     389                         configs_dict=self.configs_dict,
#     390
#     391                         plot_final_res=False,
#     392                         plot_every=plot_every,
#     393                         verbose=verbose,
#     394                         verbose_in_funcs=verbose_in_funcs,
#     395                         **fit_opt_params,
#     396
#     397                         **kwargs)
#     400 if verbose:
#     401     printd(f'\ntrain_model_on_params on {self.model_name} {self.dataset_name} \ntook {time.time() - t_train_model} seconds')
#
# File ~/Documents/danny/AAAI_pieclam/tests/../clamiter.py:610, in PCLAMIter.fit(self, graph, first_func_in_fit, optimizer, scheduler, n_back_forth, dyads_to_omit, prior_fit_mask, plot_every, acc_every, early_stop_fit, early_stops, performance_metric, configs_dict, task, verbose_in_funcs, verbose, **params)
#     608 t_first = time.time()
#     609 try:
# --> 610     losses_epoch_1st, accuracies_test_epoch_1st, accuracies_val_epoch_1st = first_func()
#     611 except ValueError as e:
#     612     printd(f'\nfit func. nerror in {first_func_in_fit} at iter {i}:\n {e}')
#
# File ~/Documents/danny/AAAI_pieclam/tests/../clamiter.py:532, in PCLAMIter.fit.<locals>.<lambda>()
#     519     feat_params['early_stop'] = early_stops[1]
#     522 fit_feats_func = lambda: self.fit_feats(
#     523                     graph,
#     524                     dyads_to_omit=dyads_to_omit,
#    (...)
#     529                     **feat_params,
#     530                     kwargs=params)
# --> 532 fit_prior_func = lambda: self.fit_prior(
#     533                     graph=graph,
#     534                     node_mask=prior_fit_mask,
#     535                     optimizer=optimizer,
#     536                     task=task,
#     537                     acc_every=acc_every,
#     538                     performance_metric=performance_metric,
#     539                     verbose=verbose_in_funcs,
#     540                     **prior_params,
#     541                     kwargs=params)
#     543 # FIRST AND SECOND PARAMS
#     545 second_function_name = 'fit_prior' if first_func_in_fit == 'fit_feats' else 'fit_feats'
#
# File ~/Documents/danny/AAAI_pieclam/tests/../clamiter.py:456, in PCLAMIter.fit_prior(self, graph, n_iter, optimizer, node_mask, acc_every, weight_decay, task, performance_metric, dyads_to_omit, early_stop, noise_amp, verbose, lr, plot_every, **kwargs)
#     435 def fit_prior(self,
#     436               graph,
#     437               n_iter,
#    (...)
#     450               **kwargs
#     451               ):
#     452     '''
#     453     this function optimizes the model.
#     454     noise is added to the feature optimization and to the input nodes when training.
#     455     '''
# --> 456     return self.fit_wrapper(graph=graph,
#     457                             n_iter=n_iter,
#     458                             lr=optimizer.param_groups[0]['lr'],
#     459                             task=task,
#     460                             which_fit='fit_prior',
#     461                             noise_amp=noise_amp,
#     462                             optimizer=optimizer,
#     463                             node_mask=node_mask,
#     464                             performance_metric=performance_metric,
#     465                             dyads_to_omit=dyads_to_omit,
#     466                             early_stop=early_stop,
#     467                             cutoff=0.0,
#     468                             verbose=verbose,
#     469                             acc_every=acc_every,
#     470                             plot_every=plot_every,
#     471                             kwargs=kwargs)
#
# File ~/Documents/danny/AAAI_pieclam/tests/../clamiter.py:351, in PCLAMIter.fit_wrapper(self, graph, n_iter, lr, task, which_fit, early_stop, cutoff, verbose, acc_every, plot_every, **kwargs)
#     349 for i in range(n_iter):
#     350     try:
# --> 351         loss = iter_step()
#     352         losses.append(loss.item())
#     353     except ValueError as e:
#
# File ~/Documents/danny/AAAI_pieclam/tests/../clamiter.py:281, in PCLAMIter.fit_wrapper.<locals>.iter_step_prior()
#     279 def iter_step_prior():
#     280     optimizer.zero_grad()
# --> 281     log_likelihood = self.prior.forward_ll(feat_for_prior, noise_amp,sum=False)
#     282     ll_loss = -torch.sum(log_likelihood)
#     283     loss = ll_loss
#
# File ~/Documents/danny/AAAI_pieclam/tests/../transformation.py:358, in RealNVP.forward_ll(self, x, noise_amp, sum)
#     356 if len(x.shape) == 1:
#     357     x = x.unsqueeze(0)
# --> 358 z, log_q = self.backward_xz(x, noise_amp)
#     360 log_prob = self.model.q0.log_prob(z) + log_q
#     361 if sum:
#
# File ~/Documents/danny/AAAI_pieclam/tests/../transformation.py:324, in RealNVP.backward_xz(self, x, noise_amp, limit_radius)
#     322 '''at every step of the flow, we check which of the nodes it threw too far away and we keep them with the last value they had before they went too far away. '''
#     323 #! maybe it's the definition of the prior?
# --> 324 z_out, log_det = self.flows[i].inverse(z)
#     325 z_out = torch.clamp(z_out, -1000*limit_radius, 1000*limit_radius)
#     326 #* don't have to stop z completely maybe? no need to update the mask
#
# File ~/anaconda3/envs/piegam/lib/python3.11/site-packages/normflows/flows/affine/coupling.py:266, in AffineCouplingBlock.inverse(self, z)
#     264 for i in range(len(self.flows) - 1, -1, -1):
#     265     z, log_det = self.flows[i].inverse(z)
# --> 266     log_det_tot += log_det
#     267 return z, log_det_tot
#
# KeyboardInterrupt:

# %% [markdown]
# ### Inner Prod

# %% [markdown]
# #### BIGCLAM

# %%
config_triplets = [
                    # ['feat_opt', 'n_iter', 2000],
                    # ['feat_opt', 'lr', 0.00003],
                    # ['prior_opt', 'n_iter', 1500],
                    # ['prior_opt', 'lr', 0.0000005],
                    # ['back_forth','n_back_forth', 50],
                    # ['back_forth', 'first_func_in_fit', 'feat_opt']
                ]


trainer_halfdiag_bigclam= Trainer(
                model_name='bigclam',
                task='distance',
                device=device,
                config_triplets_to_change=config_triplets,
                dataset=ds_sbm_halfdiag.clone()
)

losses_halfdiag_bigclam, logcut_halfdiag_bigclam, l2_halfdiag_bigclam = trainer_halfdiag_bigclam.train(
    d = 0.2,
    plot_every=-1,
    init_feats=True,
    init_type='small_gaus',
    verbose=False,
    verbose_in_funcs=False
)

del trainer_halfdiag_bigclam.data
# Out:
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:311:::
#  starting optimization of bigclam on sbm3x3HalfDiag on device cuda
#
#  configs_dict:
# {
#     "clamiter_init": {
#         "dim_feat": 2,
#         "dim_attr": 100,
#         "s_reg": 0.0,
#         "l1_reg": 0.01,
#         "T": 1,
#         "hidden_dim": 64,
#         "num_coupling_blocks": 32,
#         "num_layers_mlp": 2
#     },
#     "feat_opt": {
#         "lr": 1e-05,
#         "n_iter": 10000,
#         "early_stop": 0
#     }
# }
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:368:::
# fit wrapper fit_feats, plotting state at iter 9999
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:727:::
# in plot state, calling function is fit_feats
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../utils/plotting.py:355:::
# calling_function_name= 'fit_feats' : iter 1/0

# %% [markdown]
# #### PClam

# %%
# SBM
config_triplets = [
                    # ['feat_opt', 'n_iter', 2000],
                    # ['feat_opt', 'lr', 0.00003],
                    # ['prior_opt', 'n_iter', 1500],
                    # ['prior_opt', 'lr', 0.0000005],
                    # ['back_forth','n_back_forth', 50],
                    # ['back_forth', 'first_func_in_fit', 'feat_opt']
                ]


trainer_halfdiag_pclam = Trainer(
                model_name='pclam',
                task='distance',
                device=device,
                config_triplets_to_change=config_triplets,
                dataset=ds_sbm_halfdiag.clone()
)
# i want to optimize the trainer
losses_halfdiag_pclam, logcut_halfdiag_pclam, l2_halfdiag_pclam = trainer_halfdiag_pclam.train(
    d = 0.2,
    plot_every=5,
    init_feats=True,
    init_type='small_gaus',
    verbose=False,
    verbose_in_funcs=False
)
del trainer_halfdiag_pclam.data
del trainer_halfdiag_pclam.clamiter.prior.model

# %% [markdown]
# #### PClam

# %%
# SBM
config_triplets = [
                    # ['feat_opt', 'n_iter', 2000],
                    # ['feat_opt', 'lr', 0.00003],
                    # ['prior_opt', 'n_iter', 1500],
                    # ['prior_opt', 'lr', 0.0000005],
                    # ['back_forth','n_back_forth', 50],
                    # ['back_forth', 'first_func_in_fit', 'feat_opt']
                ]


trainer_halfdiag_pclam = Trainer(
                model_name='pclam',
                task='distance',
                device=device,
                config_triplets_to_change=config_triplets,
                dataset=ds_sbm_halfdiag.clone()
)
# i want to optimize the trainer
losses_halfdiag_pclam, logcut_halfdiag_pclam, l2_halfdiag_pclam = trainer_halfdiag_pclam.train(
    d = 0.2,
    plot_every=5,
    init_feats=True,
    init_type='small_gaus',
    verbose=False,
    verbose_in_funcs=False
)
del trainer_halfdiag_pclam.data
del trainer_halfdiag_pclam.clamiter.prior.model

# %% [markdown]
# ### Lorenz Inner

# %% [markdown]
# #### IEClam

# %%
config_triplets = [
                    # ['feat_opt', 'n_iter', 2000],
                    # ['feat_opt', 'lr', 0.00003],
                    # ['prior_opt', 'n_iter', 1500],
                    # ['prior_opt', 'lr', 0.0000005],
                    # ['back_forth','n_back_forth', 50],
                    # ['back_forth', 'first_func_in_fit', 'feat_opt']
                ]


trainer_halfdiag_iegam = Trainer(
                model_name='iegam',
                task='distance',
                device=device,
                config_triplets_to_change=config_triplets,
                dataset=ds_sbm_halfdiag.clone()
)

losses_halfdiag_iegam, logcut_halfdiag_iegam, l2_halfdiag_iegam = trainer_halfdiag_iegam.train(
    d = 0.2,
    plot_every=-1,
    init_feats=True,
    init_type='small_gaus',
    verbose=False,
    verbose_in_funcs=False
)

del trainer_halfdiag_iegam.data

# %% [markdown]
# #### PieClam

# %%
config_triplets = [
                    # ['feat_opt', 'n_iter', 2000],
                    # ['feat_opt', 'lr', 0.00003],
                    # ['prior_opt', 'n_iter', 1500],
                    # ['prior_opt', 'lr', 0.0000005],
                    # ['back_forth','n_back_forth', 50],
                    # ['back_forth', 'first_func_in_fit', 'feat_opt']
                ]


trainer_halfdiag_piegam = Trainer(
                model_name='piegam',
                task='distance',
                device=device,
                config_triplets_to_change=config_triplets,
                dataset=ds_sbm_halfdiag.clone()
)

losses_halfdiag_piegam, logcut_halfdiag_piegam, l2_halfdiag_piegam = trainer_halfdiag_piegam.train(
    d = 0.2,
    plot_every=-1,
    init_feats=True,
    init_type='small_gaus',
    verbose=False,
    verbose_in_funcs=False
)

del trainer_halfdiag_piegam.data
del trainer_halfdiag_piegam.clamiter.prior.model

# %% [markdown]
# ## HalfCenter

# %% [markdown]
# ### Lorenz Inner

# %% [markdown]
# #### IEClam

# %%
config_triplets = [
                    # ['feat_opt', 'n_iter', 2000],
                    # ['feat_opt', 'lr', 0.00003],
                    # ['prior_opt', 'n_iter', 1500],
                    # ['prior_opt', 'lr', 0.0000005],
                    # ['back_forth','n_back_forth', 50],
                    # ['back_forth', 'first_func_in_fit', 'feat_opt']
                ]


trainer_halfcenter_iegam = Trainer(
                model_name='iegam',
                task='distance',
                device=device,
                config_triplets_to_change=config_triplets,
                dataset=ds_sbm_halfcenter.clone()
)

losses_halfcenter_iegam, logcut_halfcenter_iegam, l2_halfcenter_iegam = trainer_halfcenter_iegam.train(
    d = 0.2,
    plot_every=-1,
    init_feats=True,
    init_type='small_gaus',
    verbose=False,
    verbose_in_funcs=False
)
del trainer_halfcenter_iegam.data

# %% [markdown]
# #### PieClam

# %%
config_triplets = [
                    # ['feat_opt', 'n_iter', 2000],
                    # ['feat_opt', 'lr', 0.00003],
                    # ['prior_opt', 'n_iter', 1500],
                    # ['prior_opt', 'lr', 0.0000005],
                    # ['back_forth','n_back_forth', 50],
                    # ['back_forth', 'first_func_in_fit', 'feat_opt']
                ]


trainer_halfcenter_piegam = Trainer(
                model_name='piegam',
                task='distance',
                device=device,
                config_triplets_to_change=config_triplets,
                dataset=ds_sbm_halfcenter.clone()
)

losses_halfcenter_piegam, logcut_halfcenter_piegam, l2_halfcenter_piegam = trainer_halfcenter_piegam.train(
    d = 0.2,
    plot_every=-1,
    init_feats=True,
    init_type='small_gaus',
    verbose=False,
    verbose_in_funcs=False
)
del trainer_halfcenter_piegam.data
del trainer_halfcenter_piegam.clamiter.prior.model

# %% [markdown]
# ### Inner Prod

# %% [markdown]
# #### BIGCLAM

# %%
config_triplets = [
                    # ['feat_opt', 'n_iter', 2000],
                    # ['feat_opt', 'lr', 0.00003],
                    # ['prior_opt', 'n_iter', 1500],
                    # ['prior_opt', 'lr', 0.0000005],
                    # ['back_forth','n_back_forth', 50],
                    # ['back_forth', 'first_func_in_fit', 'feat_opt']
                ]


trainer_halfcenter_bigclam= Trainer(
                model_name='bigclam',
                task='distance',
                device=device,
                config_triplets_to_change=config_triplets,
                dataset=ds_sbm_halfcenter.clone()
)

losses_halfcenter_bigclam, logcut_halfcenter_bigclam, l2_halfcenter_bigclam = trainer_halfcenter_bigclam.train(
    d = 0.2,
    plot_every=-1,
    init_feats=True,
    init_type='small_gaus',
    verbose=False,
    verbose_in_funcs=False
)

del trainer_halfcenter_bigclam.data
del trainer_halfcenter_bigclam.clamiter.prior.model

# %% [markdown]
# #### PClam

# %%
# SBM
config_triplets = [
                    ['feat_opt', 'n_iter', 2000],
                    ['feat_opt', 'lr', 0.00005],
                    ['prior_opt', 'n_iter', 1500],
                    ['prior_opt', 'lr', 0.0000005],
                    ['back_forth','n_back_forth', 30],
                    # ['back_forth', 'first_func_in_fit', 'feat_opt']
                ]


trainer_halfcenter_pclam = Trainer(
                model_name='pclam',
                task='distance',
                device=device,
                config_triplets_to_change=config_triplets,
                dataset=ds_sbm_halfcenter.clone()
)
# i want to optimize the trainer
losses_halfcenter_pclam, logcut_halfcenter_pclam, l2_halfcenter_pclam = trainer_halfcenter_pclam.train(
    d = 0.2,
    plot_every=5,
    init_feats=True,
    init_type='small_gaus',
    verbose=False,
    verbose_in_funcs=False
)

del trainer_halfcenter_pclam.data
del trainer_halfcenter_pclam.clamiter.prior.model
